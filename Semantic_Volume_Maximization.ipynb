# %% [markdown]
# # Semantic Volume Maximization for text summarization
# ### Yogotama et al. 2015

# %%
import numpy as np
import pandas as pd
import logging
import nltk
import scipy
import gensim
import sklearn

from pprint import pprint

import scipy.sparse
from scipy.sparse import csr_matrix
from gensim.models import Doc2Vec
import sklearn.metrics.pairwise
from gensim import corpora
from collections import defaultdict
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem.porter import PorterStemmer

logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
np.__file__
# Out:
# '/Library/Python/2.7/site-packages/numpy/__init__.pyc'

# %%
xl = pd.ExcelFile("./data/survey_data.xlsx")
df = xl.parse()
df = df.dropna()

# df.ix[:,1]
# df.shape
df.head()

# Columns to summarize: 1,2,3,4,5,6
# Out:
#    PanelistID                              What is Healthy Skin?  \
# 1       36761                             Skin free of blemishes
# 2        6756                                     no irritations
# 3       16468  Skin that is not dry, is soft to the touch, no...
# 4       11551     Skin that feels soft and has a nice glow to it
# 5        8548                             Glowing even skin tone
#
#            How do you know your skin is healthy?  \
# 1                Because it is free of blemishes
# 2                       on irritations or rashes
# 3           It has a slight shine to the surface
# 4  If it looks like it flows without any make up
# 5                      No dry spots or blemishes
#
#   How do you know your skin is getting healthier with every shower?\n  \
# 1                              My pores care closing
# 2                                            not dry
# 3                                     I have no idea
# 4                        It feels softer and tighter
# 5                                  Not dry and flaky
#
#                    How do you get healthy skin?\n  \
# 1        washing your face daily and moisturizing
# 2                           soap and moisturizing
# 3  Eat healthy, minimize sun exposure, moisturize
# 4      Using products that moisturize and protect
# 5                    Wash and moisterize and diet
#
#                    How do you maintain healthy skin?  \
# 1                 washing face and moisturizing skin
# 2                                      daily routine
# 3       eat right, moisturize, minimize sun exposure
# 4  Continue usin products and eat right and drink...
# 5                                               Diet
#
#   How Bar Soap or Body Wash gives you Healthy Skin?\n         How concerned
# 1              By cleaning it and removing dead skin    Extremely concerned
# 2                                        not dry out   Moderately concerned
# 3           It can aid in the moisturizing qualities     Slightly concerned
# 4  They can contain moisturizer to help skin cell...   Moderately concerned
# 5                         Cleans dirt and dead cells   Moderately concerned

# %%
def make_sentences(df):
    # todo - automate for each column
    tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
    textBlobs = []
    for i in range(2,3):
        if str(df.ix[:,i].dtype) == 'object':
            # Use a period as most users do not end their answers with periods
            # (Possible source of optimization)
            textBlob = df.ix[:,i].str.cat(sep='. ')
            tokenized = tokenizer.tokenize(textBlob)
            textBlobs += tokenized
            
    return np.array(textBlobs)

def do_stemming(sentences):
    stemmer = PorterStemmer()
    
    stemmed_sentences = []
    for sentence in sentences:
        words = word_tokenize(sentence)
        
        stemmed_sentence = []
        for w in words:
            stemmed_sentence.append(stemmer.stem(w))
        stemmed_sentences.append(' '.join(stemmed_sentence))
        
    return stemmed_sentences

# Todo - only removes first stopword of bigram
def remove_stopword_bigrams(sentences):
    sw_bigrams_removed = []
    for sentence in sentences:
        bigrams = nltk.bigrams(sentence.split())
        stopwords = nltk.corpus.stopwords.words('english')
        
        filtered = [tup for tup in bigrams if not [True for wrd in tup if wrd in stopwords].count(True) == 2]
        # Join back into sentence:
        joined = " ".join("%s" % tup[0] for tup in filtered)
        sw_bigrams_removed.append(joined)
        
    return sw_bigrams_removed

def vectorize(sentences):
    return CountVectorizer().fit_transform(sentences)

# %%
def sem_vol_max(sentences, vectors, L):
    S = set()
    B = set()
    
    # Mean vector
    c = (1 / vectors.shape[0]) * np.sum(vectors, axis=0)
    c = csr_matrix(c)
    
    # 1st furthest vector -- Will this always just be the longest sentence?
    dists = sklearn.metrics.pairwise.pairwise_distances(vectors, c)
    p = np.argmax(dists)
    print("Sentence furthest from mean: {}".format(sentences[p]))
    S.add(sentences[p])
    
    # 2nd furthest vector
    dists = sklearn.metrics.pairwise.pairwise_distances(vectors, vectors[p])
    q = np.argmax(dists)
    print("Sentence furthest from first: {}".format(sentences[q]))
    S.add(sentences[q])
    
    b_0 = vectors[q] / scipy.sparse.linalg.norm(vectors[q])
    B.add(b_0)
    
    total_length = len(sentences[p].split()) + len(sentences[q].split())
    exceeded_length_count = 0
    
    for i in range(0, vectors.shape[0]):
        print("\n" + "*"*10)
        
        r = ortho_proj_vec(vectors, B)
        print("Furthest sentence: " + sentences[r])
        print("Total words: {}".format(total_length))
        print("Length of sentence to add: {}".format(len(sentences[r].split())))
        
        new_sentence_length = len(sentences[r].split())
        
        if total_length + new_sentence_length <= L:
            S.add(sentences[r])
            b_r = np.divide(vectors[r], scipy.sparse.linalg.norm(vectors[r]))
            B.add(b_r)
            total_length = total_length + new_sentence_length
            # Reset the exceeded_length_count
            exceeded_length_count = 0
        else:
            print("Sentence too long to add to set")
            # Temporary hack to prevent us from choosing this vector again:
            vectors[r] = np.zeros(vectors[p].shape)
            
            exceeded_length_count += 1
            if exceeded_length_count >= 15:
                break
            
    print("Final sentence count: " + str(len(S)))
    return S

# %% [markdown]
# ### Computing the vector most distant from subspace spanned by basis vectors $B$
# $Distance(u_i, \beta) = \| u_i - \sum_{b_j \epsilon \beta} Proj_{b_j}(u_i) \|$

# %%
def ortho_proj_vec(vectors, B):
    print("Calculating vector with largest distance to subspace of {} basis vectors".format(len(B)))
    projs = csr_matrix(vectors.shape, dtype=np.int8) # coo_matrix
    
    iteration = 0
    for b in B:
        iteration += 1
        print("Starting with basis vector {} of {}".format(iteration, len(B)))
        
        p_i = np.multiply(vectors.dot(b.T), b)
        projs += p_i
    
    dists = scipy.sparse.linalg.norm((vectors - projs), axis=1)
    
    print("Top distance: {}".format(np.max(dists)))
    print("And its index: {}".format(np.argmax(dists)))
    return np.argmax(dists)

# %%
L = 90
delimiter = '\n' + '*'*30

print(delimiter + ' Raw sentences:')
sentences = make_sentences(df)
print(sentences[:10])

print(delimiter + ' After stemming:')
stemmed = do_stemming(sentences)
print(stemmed[:10])

print(delimiter + ' After removing stopword bigrams:')
sw_bigrams_removed = remove_stopword_bigrams(stemmed)
print(sw_bigrams_removed[:2])

print(delimiter + ' After vectorization:')
vectorized = vectorize(sw_bigrams_removed)
print(vectorized[:2])

print(delimiter + ' Run Algorithm:')
summary = sem_vol_max(sentences, vectorized, L)

print(delimiter + ' Result:')
print(summary)
# Out:
# ****************************** Raw sentences:
# [u'Because it is free of blemishes.' u'on irritations or rashes.'
#  u'It has a slight shine to the surface.'
#  u'If it looks like it flows without any make up.'
#  u'No dry spots or blemishes.' u'not dry, not blemished, healthy color.'
#  u"I can feel it and see it's appearance."
#  u'If it is off, then I know there is something wrong and I need to fix it..'
#  u'If it is firm and glowing with out a whitish tint from dryness.'
#  u'When you run your hand on your skin and it feels and looks smooth.']
#
# ****************************** After stemming:
# [u'becaus it is free of blemish .', u'on irrit or rash .', u'It ha a slight shine to the surfac .', u'If it look like it flow without ani make up .', u'No dri spot or blemish .', u'not dri , not blemish , healthi color .', u"I can feel it and see it 's appear .", u'If it is off , then I know there is someth wrong and I need to fix it..', u'If it is firm and glow with out a whitish tint from dryness .', u'when you run your hand on your skin and it feel and look smooth .']
#
# ****************************** After removing stopword bigrams:
# [u'becaus is free of blemish', u'on irrit or rash']
#
# ****************************** After vectorization:
#   (0, 39)	1
#   (0, 246)	1
#   (0, 149)	1
#   (0, 182)	1
#   (0, 34)	1
#   (1, 282)	1
#   (1, 255)	1
#   (1, 181)	1
#   (1, 251)	1
#
# ****************************** Run Algorithm:
# Sentence furthest from mean: I know that my skin is healthy because I wash it daily with a gentle cleanser.. first by the look (not dry or red)
# second by the glow of the skin (not greasy)
# third firmness of the skin and no visible blemish or markings.. when there are no blemishes and the skin is soft and smooth to the touch.
# Sentence furthest from first: Also it has a nice glow to it.. Again, not to dry not to oily, a glow??.
#
# **********
# Calculating vector with largest distance to subspace of 1 basis vectors
# Starting with basis vector 1 of 1
# Top distance: 9.74233254813
# And its index: 374
# Furthest sentence: I know that my skin is healthy because I wash it daily with a gentle cleanser.. first by the look (not dry or red)
# second by the glow of the skin (not greasy)
# third firmness of the skin and no visible blemish or markings.. when there are no blemishes and the skin is soft and smooth to the touch.
# Total words: 76
# Length of sentence to add: 59
# Sentence too long to add to set
#
# **********
# Calculating vector with largest distance to subspace of 1 basis vectors
# Starting with basis vector 1 of 1
# Top distance: 6.62997147348
# And its index: 311
# Furthest sentence: I only think my skin is healthy because of limited sun damage and not many blemished.. My skin is normal color, not overly dry or greasy and I don't develop rashes from different products that I might try.. smooth, soft.
# Total words: 76
# Length of sentence to add: 40
# Sentence too long to add to set
#
# **********
# Calculating vector with largest distance to subspace of 1 basis vectors
# Starting with basis vector 1 of 1
# Top distance: 6.23105825334
# And its index: 116
# Furthest sentence: When It looks and feels nourished and free of dead skin cells.. My skin is healthy because I have no marks and it is moisturize all the time.. Blemish free and smooth.
# Total words: 76
# Length of sentence to add: 32
# Sentence too long to add to set
#
# **********
# Calculating vector with largest distance to subspace of 1 basis vectors
# Starting with basis vector 1 of 1
# Top distance: 5.79730072121
# And its index: 73
# Furthest sentence: When my skin feels soft, hydrated (not dry to the touch, not itchy and flaky) and looks an even skin tone and bright, I know it's healthy.
# Total words: 76
# Length of sentence to add: 27
# Sentence too long to add to set
#
# **********
# Calculating vector with largest distance to subspace of 1 basis vectors
# Starting with basis vector 1 of 1
# Top distance: 5.59502884944
# And its index: 164
# Furthest sentence: My skin glows and is clear from me eating the right foods and using the right products for my skin type.. when it doesn't itch from winter dryness.
# Total words: 76
# Length of sentence to add: 28
# Sentence too long to add to set
#
# **********
# Calculating vector with largest distance to subspace of 1 basis vectors
# Starting with basis vector 1 of 1
# Top distance: 5.56385852976
# And its index: 64
# Furthest sentence: Soft.. No flaking, not itching, smooth and soft feel and appearance.. if it is not dry and peeling, no rashes or acne.
# Total words: 76
# Length of sentence to add: 22
# Sentence too long to add to set
#
# **********
# Calculating vector with largest distance to subspace of 1 basis vectors
# Starting with basis vector 1 of 1
# Top distance: 5.08193732316
# And its index: 187
# Furthest sentence: It will look clean, clear, and not rashy or red or blotchy.. Supple and moist skin; no acne; break outs; or rashes..
# Total words: 76
# Length of sentence to add: 22
# Sentence too long to add to set
#
# **********
# Calculating vector with largest distance to subspace of 1 basis vectors
# Starting with basis vector 1 of 1
# Top distance: 4.99565028191
# And its index: 289
# Furthest sentence: My skin is a dry, but there is no discoloration or sores.. My skin doesn't flake or feel rough because it is soft and smooth.
# Total words: 76
# Length of sentence to add: 25
# Sentence too long to add to set
#
# **********
# Calculating vector with largest distance to subspace of 1 basis vectors
# Starting with basis vector 1 of 1
# Top distance: 4.96071523595
# And its index: 132
# Furthest sentence: I know my skin is healthy because it feels smooth to the touch and when viewing in the mirror, I can tell that it is healthy.. not dry.
# Total words: 76
# Length of sentence to add: 28
# Sentence too long to add to set
#
# **********
# Calculating vector with largest distance to subspace of 1 basis vectors
# Starting with basis vector 1 of 1
# Top distance: 4.85887802401
# And its index: 197
# Furthest sentence: I try and use good products when I wash and I make sure to lotion one or two times a day.. if the elasticity is still there.
# Total words: 76
# Length of sentence to add: 27
# Sentence too long to add to set
#
# **********
# Calculating vector with largest distance to subspace of 1 basis vectors
# Starting with basis vector 1 of 1
# Top distance: 4.82745769801
# And its index: 100
# Furthest sentence: If it's radiant and has an even skin tone and doesn't look irritated or overly dry or overly oily..
# Total words: 76
# Length of sentence to add: 19
# Sentence too long to add to set
#
# **********
# Calculating vector with largest distance to subspace of 1 basis vectors
# Starting with basis vector 1 of 1
# Top distance: 4.69041575982
# And its index: 337
# Furthest sentence: Soft smooth no rashes no dryness no cracking no shafing.
# Total words: 76
# Length of sentence to add: 10
#
# **********
# Calculating vector with largest distance to subspace of 2 basis vectors
# Starting with basis vector 1 of 2
# Starting with basis vector 2 of 2
# Top distance: 4.65234013962
# And its index: 34
# Furthest sentence: It feels and looks soft, smooth and rested.. feels and looks good.
# Total words: 86
# Length of sentence to add: 12
# Sentence too long to add to set
#
# **********
# Calculating vector with largest distance to subspace of 2 basis vectors
# Starting with basis vector 1 of 2
# Starting with basis vector 2 of 2
# Top distance: 4.57307811854
# And its index: 172
# Furthest sentence: I use pump soap and water then astringent on a cotton pad to remove any dirt or grime that washing did not remove.. it feels good.
# Total words: 86
# Length of sentence to add: 26
# Sentence too long to add to set
#
# **********
# Calculating vector with largest distance to subspace of 2 basis vectors
# Starting with basis vector 1 of 2
# Starting with basis vector 2 of 2
# Top distance: 4.50603460108
# And its index: 104
# Furthest sentence: You could tell its healthy by its look and feel.. You can see that it is bright and free of blemishes.
# Total words: 86
# Length of sentence to add: 21
# Sentence too long to add to set
#
# **********
# Calculating vector with largest distance to subspace of 2 basis vectors
# Starting with basis vector 1 of 2
# Starting with basis vector 2 of 2
# Top distance: 4.45264943113
# And its index: 55
# Furthest sentence: My skin is healthy when it does not secrete too much oil and does not feel tight.
# Total words: 86
# Length of sentence to add: 17
# Sentence too long to add to set
# Final sentence count: 3
#
# ****************************** Result:
# set([u'Soft smooth no rashes no dryness no cracking no shafing.', u'Also it has a nice glow to it.. Again, not to dry not to oily, a glow??.', u'I know that my skin is healthy because I wash it daily with a gentle cleanser.. first by the look (not dry or red)\nsecond by the glow of the skin (not greasy)\nthird firmness of the skin and no visible blemish or markings.. when there are no blemishes and the skin is soft and smooth to the touch.'])
